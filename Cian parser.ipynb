# %%
import cianparser
 
for i in range(1, 100):
    data = cianparser.parse(
    deal_type="sale",
    accommodation_type="flat",
    location="Москва",
    rooms=(2),
    start_page=i,
    end_page=i,
    is_saving_csv=True,
    is_latin=False,
    is_express_mode=True,
    )

print(data[0])
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# C:\Users\rodio\OneDrive\Документы\cian\cian_parsing_result_sale_1400_1400_moskva_25_Apr_2023_19_25_52_996763.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1400&region=1&offer_type=flat&deal_type=sale&room2=1&with_neighbors=0
#
# ...
#  1 | 1400 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 105 529 962 rub
#
# The collection of information from the pages with list of announcements is completed
# Total number of parced announcements: 28. Average price: 105 529 962 rub
#
#
#                               Preparing to collect information from pages..
# The absolute path to the file:
# C:\Users\rodio\OneDrive\Документы\cian\cian_parsing_result_sale_1401_1401_moskva_25_Apr_2023_19_25_58_245569.csv
#
# ...
